# %% [markdown]
# ### 堆
# 堆是图的一种树形结构，被用于实现“优先队列”。优先队列是中数据结构，自由添加数据，取出数据时候先取出最小的值。
# #### 特点
# - 堆的节点中存储的是数据
# - 每个节点最多两个子节点
# - 子节点的数据必须大于父节点
# - 最小值存储于最顶端，即根节点的位置上
# - 树的形状取决于数据的个数
# - 节点的排列顺序：
#      - 从左到右
#      - 从上到下
#
# #### 输入数据
# - 插入左右边，再和父节点比较
# - 如果比父节点小，交换位置
# - 重复上面的步骤，直至父节点都是小于子节点
# ![image.png](attachment:image.png)
#
# #### 取出数据
# - 先取出根节点的数据
# - 将最右端的数据放在根节点上
# - 再进行父节点和子节点的比较，满足父节点<子节点
# - 比较顺序：左右，上下
#
# #### 时间复杂度
# - 取出顶端数据的复杂度是O(1)
# - 假设数据量是n，树的高度是$log_2{n}$，时间复杂度是$O(log_2{n})

# %% [markdown]
# ### 二叉树
# 二叉查找树是一种树形结构，采用了图的树形结构。每个节点最多两个子节点
# - 平衡二叉树：修正不均衡的树，保持均衡状态，提高查找效率
# - B树：每个节点不止一个子节点，可以多个；MySQL中用到了B树
#
# 特点：
# - 每个节点的值均大于其左子树上任意一个节点的值：`大于左边`
# - 每个节点的值均小于其右子树上任意一个节点的值：`小于右边`
# ![image.png](attachment:image.png)
#
# #### 添加数据
# - 从根节点开始比较
# - 小于跟节点放在左边，大于在右边
# - 如果某边已经有了数据，直接放在它的下面
#
# #### 删除数据
# - 如果删除的数据没有子节点：直接删除
# - 如果有一个子节点：先删除目标点，再把子节点补上去
# - 如果有多个节点：先删除目标点，再把左子树中的最大值填充在目标点的位置，就满足了父节点大于左子节点的每个数
#
# #### 时间复杂度
# - 假设节点数是n，而且数的形状是均衡的，比较和移动的次数是$log_2{n}$，时间复杂度是$Olog(n)$。
# - 如果树朝着某个方向纵向延伸，复杂度变成$O(n)$
